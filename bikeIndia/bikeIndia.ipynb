# %%
import requests
from bs4 import BeautifulSoup
import os
import re

# Load URLs from a plain text file (one URL per line)
url_file_path = 'allUrls.csv'
with open(url_file_path, 'r') as file:
    urls = [line.strip() for line in file if line.strip()]

# Function to sanitize URL for filenames
def sanitize_filename(url):
    return re.sub(r'[^a-zA-Z0-9_-]', '_', url)

# Directory to save output files
output_dir = 'url_outputs'
os.makedirs(output_dir, exist_ok=True)

# Iterate over URLs and process each
for url in urls:
    try:
        # Request page content
        response = requests.get(url)
        response.raise_for_status()
        
        # Parse HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract title and body text based on provided CSS selectors
        title = soup.select_one('body > div.site-container > div > div > main > article > header > h1')
        body_text = soup.select_one('body > div.site-container > div > div > main > article > div')
        
        # Get text and sanitize for output
        title_text = title.get_text(strip=True) if title else 'No Title'
        
        # Remove the `div.author_info` content
        author_info = body_text.select_one('div.author_info') if body_text else None
        if author_info:
            author_info.decompose()
        
        # Get all paragraphs within the body div
        paragraphs = body_text.find_all('p') if body_text else []
        body_text_content = "\n\n".join(p.get_text(strip=True) for p in paragraphs)

        # Create a filename based on the URL
        filename = sanitize_filename(url) + '.txt'
        file_path = os.path.join(output_dir, filename)
        
        # Write content to file
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(f"Title: {title_text}\n\n")
            f.write(f"Body Text:\n{body_text_content}")
        
        print(f"Content for {url} saved to {file_path}")

    except Exception as e:
        print(f"Failed to retrieve or parse {url}: {e}")
# Out:
# Content for https://bikeindia.in/bajaj-pulsar-n125-review-a-fresh-proposition/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-n125-review-a-fresh-proposition_.txt
# Content for https://bikeindia.in/bajaj-dominar-ladakh-tour-over-the-hills-and-far-away/ saved to url_outputs/https___bikeindia_in_bajaj-dominar-ladakh-tour-over-the-hills-and-far-away_.txt
# Content for https://bikeindia.in/bajaj-freedom-125-ng04-review-%e2%80%a8gas-and-gasoline/ saved to url_outputs/https___bikeindia_in_bajaj-freedom-125-ng04-review-_e2_80_a8gas-and-gasoline_.txt
# Content for https://bikeindia.in/spec-comparo-bajaj-freedom-125-v-rivals/ saved to url_outputs/https___bikeindia_in_spec-comparo-bajaj-freedom-125-v-rivals_.txt
# Content for https://bikeindia.in/bajaj-freedom-125-launched-as-the-worlds-first-cng-motorcycle/ saved to url_outputs/https___bikeindia_in_bajaj-freedom-125-launched-as-the-worlds-first-cng-motorcycle_.txt
# Content for https://bikeindia.in/spec-comparo-bajaj-pulsar-ns400z-v-rivals/ saved to url_outputs/https___bikeindia_in_spec-comparo-bajaj-pulsar-ns400z-v-rivals_.txt
# Content for https://bikeindia.in/all-new-bajaj-pulsar-ns400z-launched-in-india/ saved to url_outputs/https___bikeindia_in_all-new-bajaj-pulsar-ns400z-launched-in-india_.txt
# Content for https://bikeindia.in/bajaj-pulsar-n250-2024-review-what-it-should-have-always-been/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-n250-2024-review-what-it-should-have-always-been_.txt
# Content for https://bikeindia.in/bajaj-pulsar-n250-2024-launched-at-rs-1-51-lakh/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-n250-2024-launched-at-rs-1-51-lakh_.txt
# Content for https://bikeindia.in/bajaj-auto-launch-new-pulsar-ns160-and-ns200/ saved to url_outputs/https___bikeindia_in_bajaj-auto-launch-new-pulsar-ns160-and-ns200_.txt
# Content for https://bikeindia.in/mobility-on-two-wheels-bharat-mobility-global-expo-2024/ saved to url_outputs/https___bikeindia_in_mobility-on-two-wheels-bharat-mobility-global-expo-2024_.txt
# Content for https://bikeindia.in/chetak-gets-a-mid-life-update/ saved to url_outputs/https___bikeindia_in_chetak-gets-a-mid-life-update_.txt
# Content for https://bikeindia.in/triumph-scrambler-400-x-first-ride-review/ saved to url_outputs/https___bikeindia_in_triumph-scrambler-400-x-first-ride-review_.txt
# Content for https://bikeindia.in/bajaj-pulsar-n250-long-term-report/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-n250-long-term-report_.txt
# Content for https://bikeindia.in/triumph-speed-400-first-ride-review/ saved to url_outputs/https___bikeindia_in_triumph-speed-400-first-ride-review_.txt
# Content for https://bikeindia.in/bajaj-and-triumph-launch-next-phase-of-partnership/ saved to url_outputs/https___bikeindia_in_bajaj-and-triumph-launch-next-phase-of-partnership_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns-160-and-ns-200-update-review-enhanced-agility/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-ns-160-and-ns-200-update-review-enhanced-agility_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns200-and-ns160-gets-usd-forks/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-ns200-and-ns160-gets-usd-forks_.txt
# Content for https://bikeindia.in/bajaj-ct-125x-first-ride-review/ saved to url_outputs/https___bikeindia_in_bajaj-ct-125x-first-ride-review_.txt
# Content for https://bikeindia.in/chetak-2022-update-marginal-difference/ saved to url_outputs/https___bikeindia_in_chetak-2022-update-marginal-difference_.txt
# Content for https://bikeindia.in/bajaj-pulsar-n160-first-ride-review-the-easygoing-n/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-n160-first-ride-review-the-easygoing-n_.txt
# Content for https://bikeindia.in/bajaj-auto-announces-new-electric-vehicle-manufacturing-unit/ saved to url_outputs/https___bikeindia_in_bajaj-auto-announces-new-electric-vehicle-manufacturing-unit_.txt
# Content for https://bikeindia.in/2022-bajaj-dominar-400-highway-dominator/ saved to url_outputs/https___bikeindia_in_2022-bajaj-dominar-400-highway-dominator_.txt
# Content for https://bikeindia.in/bajaj-pulsar-f250-and-n250-review-specs-price/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-f250-and-n250-review-specs-price_.txt
# Content for https://bikeindia.in/bajaj-auto-ev-focused-brand-to-be-introduced/ saved to url_outputs/https___bikeindia_in_bajaj-auto-ev-focused-brand-to-be-introduced_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns125-need-to-know/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar
 saved to url_outputs/https___bikeindia_in_bajaj-pulsar-150-classic-undercuts-the-pulsar-150_.txt
# Content for https://bikeindia.in/official-bajaj-to-launch-electric-two-wheeler-by-2020/ saved to url_outputs/https___bikeindia_in_official-bajaj-to-launch-electric-two-wheeler-by-2020_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns-160-abs-incoming/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-ns-160-abs-incoming_.txt
# Content for https://bikeindia.in/spec-comparo-bajaj-ns-200-v-hero-xtreme-200r-v-tvs-apache-rtr200-4v/ saved to url_outputs/https___bikeindia_in_spec-comparo-bajaj-ns-200-v-hero-xtreme-200r-v-tvs-apache-rtr200-4v_.txt
# Content for https://bikeindia.in/bajaj-avenger-street-180-road-test-review-pocket-friendly-cruiser/ saved to url_outputs/https___bikeindia_in_bajaj-avenger-street-180-road-test-review-pocket-friendly-cruiser_.txt
# Content for https://bikeindia.in/2018-bajaj-pulsar-150-gets-front-and-rear-disc-brakes/ saved to url_outputs/https___bikeindia_in_2018-bajaj-pulsar-150-gets-front-and-rear-disc-brakes_.txt
# Content for https://bikeindia.in/first-ride-review-bajaj-avenger-180-street-launched-and-ridden/ saved to url_outputs/https___bikeindia_in_first-ride-review-bajaj-avenger-180-street-launched-and-ridden_.txt
# Content for https://bikeindia.in/2018-bajaj-avenger-180-street/ saved to url_outputs/https___bikeindia_in_2018-bajaj-avenger-180-street_.txt
# Content for https://bikeindia.in/season-three-of-the-bajaj-festival-of-speed-concludes/ saved to url_outputs/https___bikeindia_in_season-three-of-the-bajaj-festival-of-speed-concludes_.txt
# Content for https://bikeindia.in/bajaj-avenger-180-street-bookings-begin/ saved to url_outputs/https___bikeindia_in_bajaj-avenger-180-street-bookings-begin_.txt
# Content for https://bikeindia.in/2018-bajaj-avenger-220-range-unveiled/ saved to url_outputs/https___bikeindia_in_2018-bajaj-avenger-220-range-unveiled_.txt
# Content for https://bikeindia.in/shootout-bajaj-pulsar-ns160-v-honda-hornet-160r/ saved to url_outputs/https___bikeindia_in_shootout-bajaj-pulsar-ns160-v-honda-hornet-160r_.txt
# Content for https://bikeindia.in/save-money-on-buying-a-two-wheeler/ saved to url_outputs/https___bikeindia_in_save-money-on-buying-a-two-wheeler_.txt
# Content for https://bikeindia.in/bajaj-to-launch-two-new-models-in-january-2018/ saved to url_outputs/https___bikeindia_in_bajaj-to-launch-two-new-models-in-january-2018_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns200-launched-with-abs/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-ns200-launched-with-abs_.txt
# Content for https://bikeindia.in/eight-things-you-should-know-about-bajaj-pulsar-ns-160/ saved to url_outputs/https___bikeindia_in_eight-things-you-should-know-about-bajaj-pulsar-ns-160_.txt
# Content for https://bikeindia.in/bajaj-pulsar-ns-160-launched-in-india/ saved to url_outputs/https___bikeindia_in_bajaj-pulsar-ns-160-launched-in-india_.txt
# Content for https://bikeindia.in/2017-best-bikes-in-india-in-the-250-cc-category/ saved to url_outputs/https___bikeindia_in_2017-best-bikes-in-india-in-the-250-cc-category_.txt
