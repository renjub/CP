# %%
import asyncio
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from IPython import get_ipython
import subprocess

# Base URL for the bike reviews
base_url = 'https://www.motorbeam.com/tag/bike-reviews/page/'

# Open a file to log the output
log_file = open("output_log.txt", "w")

# Function to log messages to the file
def log_message(message):
    print(message)  # Print to console as well (optional)
    log_file.write(message + "\n")

# Function to read the value of #content > nav > div > div > ul > li:nth-child(5) > a
async def read_last_page(page):
    try:
        page_element = page.locator("#content > nav > div > div > ul > li:nth-child(5) > a")
        last_page_number = await page_element.inner_text()
        last_page_number = last_page_number.strip()
        log_message(f"Last page number detected: {last_page_number}")
        return int(last_page_number)
    except Exception as e:
        log_message(f"Error while reading the last page number: {e}")
        return None

# Function to extract link addresses from the specific selector
async def extract_links(page):
    try:
        # Get the page content and parse it using BeautifulSoup
        content = await page.content()
        soup = BeautifulSoup(content, 'html.parser')

        # Extract the links using the provided CSS selector
        link_elements = soup.select('h2.entry-title > a')

        # Log the extracted links
        for link in link_elements:
            href = link.get('href')
            log_message(href)
    except Exception as e:
        log_message(f"An error occurred while extracting links: {e}")

# Function to increment pages until the last page is reached
async def navigate_pages(page, current_page, last_page):
    while current_page <= last_page:
        log_message(f"Navigating to page {current_page}...")
        # Navigate to the next page
        await page.goto(f'{base_url}{current_page}/')
        
        # Extract links from the current page
        await extract_links(page)
        
        # Increment the current page
        current_page += 1

async def main():
    try:
        # Ensure the necessary browser is installed
        subprocess.run(["playwright", "install"], check=True)

        async with async_playwright() as p:
            # Launch the browser in headless mode
            browser = await p.chromium.launch(headless=True)
            page = await browser.new_page()

            # Load the first webpage
            current_page = 0
            await page.goto(f'{base_url}{current_page}/')

            # Read the last page number
            last_page = await read_last_page(page)

            # Start the navigation process
            if last_page:
                await navigate_pages(page, current_page + 1, last_page)

            log_message("Finished navigating through the pages and extracting links.")
            await browser.close()
    except Exception as e:
        log_message(f"An error occurred during execution: {e}")
    finally:
        log_file.close()  # Ensure the log file is closed properly

# Check if running in Jupyter Notebook and run the main function accordingly
if get_ipython() is not None and "IPKernelApp" in get_ipython().config: 
    try:
        loop = asyncio.get_running_loop()
        if loop.is_running():
            loop.create_task(main())
    except RuntimeError:
        asyncio.run(main())
else:
    asyncio.run(main())
# Out:
# Last page number detected: 49
# Navigating to page 2...
# https://www.motorbeam.com/zontes-350r-video-review/
# https://www.motorbeam.com/moto-morini-seiemmezzo-video-review/
# https://www.motorbeam.com/zontes-350t-video-review/
# https://www.motorbeam.com/new-tvs-radeon-110-review-video/
# https://www.motorbeam.com/2023-kawasaki-versys-650-review-video/
# https://www.motorbeam.com/ducati-hypermotard-950-rve-video-review/
# https://www.motorbeam.com/royal-enfield-hunter-350-vs-honda-cb350rs-comparison-video-hindi/
# https://www.motorbeam.com/keeway-sixties-300i-video-review/
# Navigating to page 3...
# https://www.motorbeam.com/bmw-f-850-gs-adventure-video-review/
# https://www.motorbeam.com/honda-cb300f-first-look-video/
# https://www.motorbeam.com/royal-enfield-hunter-350-video-review/
# https://www.motorbeam.com/simple-one-video-review/
# https://www.motorbeam.com/bajaj-puslar-n160-video-review/
# https://www.motorbeam.com/hero-xtreme-200s-review-test-ride/
# Navigating to page 21...
# https://www.motorbeam.com/hero-xpulse-200-200t-video-review/
# https://www.motorbeam.com/kawasaki-ninja-400-video-review/
# https://www.motorbeam.com/royal-enfield-interceptor-650-video-review/
# https://www.motorbeam.com/royal-enfield-bullet-trials-review-test-ride/
# https://www.motorbeam.com/royal-enfield-bullet-trials-video-review/
# https://www.motorbeam.com/swm-superdual-t-review-test-ride/
# https://www.motorbeam.com/yamaha-mt-15-review-test-ride/
# https://www.motorbeam.com/yamaha-mt-15-video-review/
# Navigating to page 22...
# https://www.motorbeam.com/2019-bajaj-dominar-400-review-test-ride/
# https://www.motorbeam.com/2019-dominar-400-video-review/
# https://www.motorbeam.com/benelli-trk-502-502x-review-test-ride/
# https://www.motorbeam.com/benelli-trk-502-video-review/
# https://www.motorbeam.com/honda-gold-wing-review-test-ride/
# https://www.motorbeam.com/honda-cb1100-rs-review-test-ride/
# https://www.motorbeam.com/honda-vfr-1200x-crosstourer-x-review-test-ride/
# https://www.motorbeam.com/honda-cbr500r-review-test-ride/
# Navigating to page 23...
# https://www.motorbeam.com/kawasaki-vulcan-s-video-review/
# https://www.motorbeam.com/royal-enfield-continental-gt-650-review-test-ride/
# https://www.motorbeam.com/kawasaki-vulcan-s-review-test-ride/
# https://www.motorbeam.com/ktm-duke-125-review-test-ride-is-the-baby-ktm-worth-it/
# https://www.motorbeam.com/ktm-duke-125-pros-cons-in-hindi-video/
# https://www.motorbeam.com/ktm-duke-125-video-review/
# https://www.motorbeam.com/2018-tvs-radeon-review-test-ride/
# https://www.motorbeam.com/hero-destini-125-review-test-ride/
# Navigating to page 24...
# https://www.motorbeam.com/harley-davidson-street-rod-review-test-ride/
# https://www.motorbeam.com/suzuki-v-strom-650xt-review-test-ride/
# https://www.motorbeam.com/suzuki-v-strom-650xt-video-review/
# https://www.motorbeam.com/triumph-bonneville-speedmaster-review-test-ride/
# https://www.motorbeam.com/tron-x-one-video-review-hindi/
# https://www.motorbeam.com/tron-x-one-review-test-ride/
# https://www.motorbeam.com/2018-honda-activa-5g-review-test-ride/
# https://www.motorbeam.com/suzuki-burgman-street-review-test-ride/
# Navigating to page 25...
# https://www.motorbeam.com/2018-bmw-g-310-r-review-test-ride/
# https://www.motorbeam.com/bmw-g-310-gs-review-test-ride/
# https://www.motorbeam.com/bmw-g-310-gs-video-review/
# https://www.motorbeam.com/bmw-g-310-r-video-review/
# https://www.motorbeam.com/2018-honda-cbr650f-video-review/
# https://www.motorbeam.com/yamaha-r15-v3-video-review/
# https://www.motorbeam.com/yamaha-r15-v3-road-test-review/
# https://www.motorbeam.com/triumph-bonneville-bobber-review-test-ride/
# Navigating to page 26...
# https://www.motorbeam.com/ather-450-review-test-ride/
# https://www.motorbeam.com/2018-honda-cbr650f-review-test-ride/
# https://www.motorbeam.com/hero-xtreme-200r-video-review/
# https://www.motorbeam.com/hero-xtreme-200r-review-test-ride/
# https://www.motorbeam.com/harley-davidson-heritage-classic-test-ride-review/
# https://www.motorbeam.com/2018-suzuki-gsx-s750-review-test-ride/
# https://www.motorbeam.com/2018-suzuki-gsx-s750-video-review/
# https://www.motorbeam.com/mv-agusta-f3-800-review-test-ride/
# Navigating to page 27...
# https://www.motorbeam.com/honda-x-blade-review-test-ride/
# https://www.motorbeam.com/honda-x-blade-video-review/
# https://www.motorbeam.com/ducati-monster-797-review-test-ride/
# https://www.motorbeam.com/2018-indian-scout-bobber-review-test-ride/
# https://www.motorbeam.com/royal-enfield-thunderbird-500x-review-test-ride/
# https://www.motorbeam.com/mv-agusta-brutale-800-review-test-ride/
# https://www.motorbeam.com/2018-tvs-apache-160-4v-review-test-ride/
# https://www.motorbeam.com/2018-tvs-apache-160-video-review/
# Navigating to page 28...
# https://www.motorbeam.com/indian-chieftain-dark-horse-review-test-ride/
# https://www.motorbeam.com/aprilia-sr-125-video-review/
# https://www.motorbeam.com/yamaha-r15-v3-review-test-ride/
# https://www.motorbeam.com/2018-yamaha-r15-v3-video-review/
# https://www.motorbeam.com/2018-bajaj-avenger-180-video-review/
# https://www.motorbeam.com/2018-bajaj-avenger-180-review-test-ride/
# https://www.motorbeam.com/harley-davidson-street-bob-review-test-ride/
# https://www.motorbeam.com/ducati-supersport-s-review-test-ride/
# Navigating to page 29...
# https://www.motorbeam.com/triumph-street-triple-rs-review-test-drive/
# https://www.motorbeam.com/bajaj-discover-110-review-test-ride/
# https://www.motorbeam.com/ducati-multistrada-950-review-test-ride/
# https://www.motorbeam.com/bajaj-pulsar-220-review-test-ride/
# https://www.motorbeam.com/2017-yamaha-fazer-25-review-test-ride/
# https://www.motorbeam.com/aprilia-rsv4-rf-review-test-ride/
# https://www.motorbeam.com/2017-ktm-duke-200-review-test-ride/
# https://www.motorbeam.com/2017-pulsar-135-ls-review-test-ride/
# Navigating to page 30...
# https://www.motorbeam.com/yamaha-fazer-25-video-review/
# https://www.motorbeam.com/tvs-apache-rr-310-video-review/
# https://www.motorbeam.com/tvs-apache-rr-310-review-first-ride/
# https://www.motorbeam.com/yamaha-mt-09-review-test-ride/
# https://www.motorbeam.com/2017-pulsar-150-review-test-ride/
# https://www.motorbeam.com/honda-grazia-review-test-ride/
# https://www.motorbeam.com/honda-grazia-video-review/
# https://www.motorbeam.com/suzuki-intruder-150-review-test-ride/
# Navigating to page 31...
# https://www.motorbeam.com/suzuki-intruder-150-video-review/
# https://www.motorbeam.com/2017-pulsar-ns-160-review-test-ride/
# https://www.motorbeam.com/2017-ktm-duke-390-review-test-ride/
# https://www.motorbeam.com/2017-ktm-duke-250-review-test-ride/
# https://www.motorbeam.com/honda-cliq-video-review/
# https://www.motorbeam.com/honda-cliq-review-test-ride/
# https://www.motorbeam.com/royal-enfield-himalayan-fi-video-review/
# https://www.motorbeam.com/royal-enfield-himalayan-fi-review-test-ride/
# Navigating to page 32...
# https://www.motorbeam.com/benelli-302r-review-test-ride/
# https://www.motorbeam.com/um-renegade-commando-classic-mojave-test-ride-review/
# https://www.motorbeam.com/um-renegade-commando-classic-mojave-video-review/
# https://www.motorbeam.com/triumph-tiger-800-review-test-ride/
# https://www.motorbeam.com/ducati-multistrada-1200-enduro-review-test-ride/
# https://www.motorbeam.com/honda-africa-twin-video-review-in-india/
# https://www.motorbeam.com/2017-ktm-duke-390-road-test-video/
# https://www.motorbeam.com/pulsar-ns-160-video-review/
# Navigating to page 33...
# https://www.motorbeam.com/honda-africa-twin-review-test-ride-in-india/
# https://www.motorbeam.com/yamaha-fz25-review-test-ride/
# https://www.motorbeam.com/yamaha-fz25-road-test-video/
# https://www.motorbeam.com/2017-honda-activa-4g-review-test-ride/
# https://www.motorbeam.com/2017-honda-activa-4g-video-review/
# https://www.motorbeam.com/2017-triumph-bonneville-t100-review-test-ride/
# https://www.motorbeam.com/2017-ktm-duke-390-video-review/
# https://www.motorbeam.com/2017-ktm-duke-200-video-review/
# Navigating to page 34...
# https://www.motorbeam.com/yamaha-fz25-video-review/
# https://www.motorbeam.com/ktm-duke-250-video-review/
# https://www.motorbeam.com/2017-ktm-rc-390-review-test-ride/
# https://www.motorbeam.com/2017-pulsar-rs-200-video-review/
# https://www.motorbeam.com/2017-indian-scout-review-test-ride/
# https://www.motorbeam.com/2017-pulsar-180-video-review/
# https://www.motorbeam.com/2017-pulsar-135-ls-video-review/
# https://www.motorbeam.com/2017-pulsar-150-video-review/
# Navigating to page 35...
# https://www.motorbeam.com/2017-pulsar-220f-video-review/
# https://www.motorbeam.com/2017-pulsar-200-ns-video-review/
# https://www.motorbeam.com/2017-ktm-rc-200-video-review/
# https://www.motorbeam.com/2017-ktm-rc-390-video-review/
# https://www.motorbeam.com/bajaj-v12-review-test-ride/
# https://www.motorbeam.com/bajaj-dominar-400-review-test-ride/
# https://www.motorbeam.com/bajaj-dominar-400-video-review/
# https://www.motorbeam.com/2017-hero-achiever-video-review/
# Navigating to page 36...
# https://www.motorbeam.com/honda-cb-unicorn-150-video-review/
# https://www.motorbeam.com/um-renegade-commando-video-review/
# https://www.motorbeam.com/2016-kawasaki-ninja-zx-14r-review-test-ride/
# https://www.motorbeam.com/mv-agusta-f4r-review-test-ride/
# https://www.motorbeam.com/aprilia-sr-150-video-review/
# https://www.motorbeam.com/2016-yamaha-ray-zr-video-review/
# https://www.motorbeam.com/2016-triumph-street-twin-review-test-ride/
# https://www.motorbeam.com/2016-kawasaki-ninja-zx-10r-review-test-ride/
# Navigating to page 37...
# https://www.motorbeam.com/aprilia-sr-150-review-first-ride/
# https://www.motorbeam.com/tvs-apache-200-fi-video-review/
# https://www.motorbeam.com/hero-splendor-ismart-110-review-first-ride/
# https://www.motorbeam.com/2016-ducati-scrambler-review-test-ride/
# https://www.motorbeam.com/2016-tvs-apache-200-review-test-ride/
# https://www.motorbeam.com/2016-suzuki-access-125-review-test-ride/
# https://www.motorbeam.com/2016-royal-enfield-himalayan-review-test-ride/
# https://www.motorbeam.com/tvs-apache-200-video-review/
# Navigating to page 38...
# https://www.motorbeam.com/2016-tvs-victor-review-test-ride/
# https://www.motorbeam.com/royal-enfield-himalayan-video-review/
# https://www.motorbeam.com/2016-hero-maestro-edge-review-test-ride/
# https://www.motorbeam.com/aprilia-tuono-v4-1100-factory-review-test-ride/
# https://www.motorbeam.com/2016-mv-agusta-brutale-1090-review-test-ride/
# https://www.motorbeam.com/2016-yamaha-r15-s-review-test-ride/
# https://www.motorbeam.com/2015-yamaha-sz-rr-version-2-0-test-ride-review/
# https://www.motorbeam.com/yamaha-fascino-test-ride-review/
# https://www.motorbeam.com/yamaha-saluto-125-test-ride-review/
# https://www.motorbeam.com/2015-kawasaki-versys-1000-test-ride-review/
# Navigating to page 45...
# https://www.motorbeam.com/suzuki-gixxer-sf-race-bike-test-ride-review/
# https://www.motorbeam.com/motomiu-katanga-uno-custom-street-750-test-ride-review/
# https://www.motorbeam.com/fortpoint-hero-impulse-223cc-karizma-engine-test-ride-review/
# https://www.motorbeam.com/bajaj-pulsar-200-as-test-ride-review/
# https://www.motorbeam.com/bajaj-pulsar-150-as-video-review/
# https://www.motorbeam.com/bajaj-pulsar-as-150-test-ride-review/
# https://www.motorbeam.com/bajaj-pulsar-rs-200-test-ride-review/
# https://www.motorbeam.com/suzuki-gixxer-sf-test-ride-review/
# Navigating to page 46...
# https://www.motorbeam.com/2015-bajaj-platina-100-es-test-ride-review/
# https://www.motorbeam.com/2015-ducati-diavel-first-ride-review/
# https://www.motorbeam.com/pulsar-rs-200-quick-ride-review-video/
# https://www.motorbeam.com/2015-indian-chieftain-test-ride-review/
# https://www.motorbeam.com/2015-ducati-panigale-899-first-ride-review/
# https://www.motorbeam.com/bajaj-pulsar-rs-200-track-test-review/
# https://www.motorbeam.com/honda-activa-3g-test-ride-review/
# https://www.motorbeam.com/bajaj-pulsar-rs-200-first-ride-review/
# Navigating to page 47...
# https://www.motorbeam.com/2015-ktm-rc-390-test-ride-review/
# https://www.motorbeam.com/hero-xtreme-sports-first-ride-review/
# https://www.motorbeam.com/2015-ktm-rc-200-test-ride-review/
# https://www.motorbeam.com/2015-benelli-tnt-300-test-ride-review/
# https://www.motorbeam.com/2015-honda-cb-unicorn-160-test-ride-review/
# https://www.motorbeam.com/2015-kawasaki-er-6n-test-ride-review/
# https://www.motorbeam.com/2015-kawasaki-z250-test-ride-review/
# https://www.motorbeam.com/2015-indian-chief-vintage-test-ride-review/
# Navigating to page 48...
# https://www.motorbeam.com/benelli-tnt-600-gt-test-ride-review/
# https://www.motorbeam.com/2015-benelli-tnt-600i-test-ride-review/
# https://www.motorbeam.com/2015-benelli-tnt-899-test-ride-review/
# https://www.motorbeam.com/2014-honda-cd-110-dream-test-ride-review/
# https://www.motorbeam.com/2014-hero-xtreme-test-ride-review/
# https://www.motorbeam.com/2014-hero-karizma-r-test-ride-review/
# https://www.motorbeam.com/2015-moto-morini-scrambler-test-ride-review/
# https://www.motorbeam.com/fortpoint-racing-modified-hero-karizma-r-test-ride-review/
# Navigating to page 49...
# https://www.motorbeam.com/2014-hero-passion-pro-tr-test-ride-review/
# https://www.motorbeam.com/2014-hero-splendor-pro-classic-test-ride-review/
# https://www.motorbeam.com/ktm-rc-390-rc-200-track-test-review/
# https://www.motorbeam.com/harley-davidson-forty-eight-test-ride-review/
# https://www.motorbeam.com/2014-mahindra-gusto-test-ride-review/
# https://www.motorbeam.com/2014-moto-morini-granpasso-test-ride-review/
# https://www.motorbeam.com/2014-hero-glamour-test-ride-review/
# https://www.motorbeam.com/2014-kawasaki-z800-test-ride-review/
# Finished navigating through the pages and extracting links.
