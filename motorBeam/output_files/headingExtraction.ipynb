# %%
import os
import re
import pandas as pd

# Function to extract bold text and associated content
def extract_content(text):
    # Remove lines containing specific phrases
    ignore_words = [
        "Bike Tested", "Price OTR",
        "Alternatives", "Road Test No", "Test Location",
        "Riders", "Picture Editing"
    ]
    text = '\n'.join([line for line in text.splitlines() if not any(word in line for word in ignore_words)])

    # Find all bold text with their positions
    pattern = r"(\*\*(.+?)\*\*)"
    matches = list(re.finditer(pattern, text))

    extracted_data = []

    for i, match in enumerate(matches):
        bold_text = match.group(0)

        # Stop parsing if 'Further Reading' is found in bold text
        if "Further Reading" in bold_text:
            break

        start = match.end()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        content = text[start:end].strip()

        # Remove lines starting with specific phrases
        content = '\n'.join([line for line in content.splitlines() if not line.startswith("Processing additional page:") and not line.startswith("Home » Bike News")])

        extracted_data.append([bold_text, content])

    return extracted_data

# Process all .txt files in the current directory
def process_txt_files():
    current_folder = os.getcwd()
    txt_files = [f for f in os.listdir(current_folder) if f.endswith('.txt')]

    if not txt_files:
        print("No .txt files found in the current folder.")
        return

    output_folder = os.path.join(current_folder, 'output_files')
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for txt_file in txt_files:
        print(f"\nProcessing file: {txt_file}")
        with open(txt_file, 'r', encoding='utf-8') as file:
            content = file.read()

        extracted_data = extract_content(content)

        # Create a DataFrame from the extracted data
        if extracted_data:
            df = pd.DataFrame(extracted_data, columns=["Bold Text", "Content"])
        else:
            # Treat the entire article as a single entry if no bold text is found or extracted_data is empty
            df = pd.DataFrame([["Full Article", content]], columns=["Bold Text", "Content"])
        
        print(df)

        # Save the DataFrame to a CSV file for each input file
        output_file = os.path.join(output_folder, f"{os.path.splitext(txt_file)[0]}_extracted.csv")
        df.to_csv(output_file, index=False)

if __name__ == "__main__":
    process_txt_files()
# Out:
# Processing file: bajaj-pulsar-rs-200-track-test-review.txt
#                         Bold Text  \
# 0  **Bajaj Pulsar RS 200 Review**
#
#                                              Content
# 0  The Pulsar RS 200 offers commendable handling ...
#
# Processing file: bajaj-pulsar-as-150-test-ride-review.txt
#                                  Bold Text  \
# 0           **Bajaj Pulsar AS 150 Review**
# 1                              **Styling**
# 2    **Instrument Cluster and Switchgear**
# 3                           **Ergonomics**
# 4                          **Performance**
# 5                      **Riding Dynamics**
# 6                              **Verdict**
# 7                          **What’s Cool**
# 8                   **What’s Not So Cool**
# 9   **Bajaj Pulsar AS 150 Specifications**
# 10      **Bajaj Pulsar AS 150 Dimensions**
#
#                                               Content
# 0   The Pulsar AS 150 brings top notch hardware an...
# 1   – Bajaj Auto have come a long way while design...
# 2   – There is no drastic change here as it is the...
# 3   – The Pulsar 150 AS being an adventure tourer ...
# 4   – The 150cc mill of the Pulsar 150 AS is all n...
# 5   – As the bike has very good ergos, riding the ...
# 6   – The most preferred motorcycle by a youth or ...
# 7   * Gadgets – projector headlamp, perimeter fram...
# 8   * Thin tyres when its rivals from Japan offer ...
# 9   * Engine: 149.5cc, air-cooled, 4-valve, single...
# 10  * Length x Width x Height: 2070 mm x 804 mm x ...
#
# Processing file: bajaj-pulsar-rs-200-first-ride-review.txt
#                   Bold Text                                            Content
# 0  **Pulsar RS 200 Review**  The RS 200 does turn attention but is quite ov...
# 1           **What’s Cool**  * Improved refinement thanks to FI, this is th...
# 2    **What’s Not So Cool**  * 20 kgs heavier over its street-fighter sibli...
#
# Processing file: bajaj-pulsar-200-as-test-ride-review.txt
#                                 Bold Text  \
# 0          **Bajaj Pulsar AS 200 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9        **Pulsar 200 AS Specifications**
# 10           **Pulsar 200 AS Dimensions**
#
#                                               Content
# 0   The Pulsar AS 200 addresses the minor shortcom...
# 1   – When the Pulsar 200 NS was launched, its des...
# 2   – The same three part instrument cluster is ca...
# 3   – While one would expect the Pulsar AS 200 to ...
# 4   – The Pulsar AS 200 uses the same engine that ...
# 5   – Bajaj Auto hasn’t played around the suspensi...
# 6   – The Pulsar AS 200 isn’t much of a new thing,...
# 7   * Small additions that make for some improveme...
# 8   * Not really an adventure bike, changes are st...
# 9   * Engine: 199.5cc, single-cylinder, carb, SOHC...
# 10  * Length x Width x Height: 2070 mm x 804 mm x ...
#
# Processing file: bajaj-v12-review-test-ride.txt
#                                 Bold Text  \
# 0                    **Bajaj V12 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9            **Bajaj V12 Specifications**
# 10               **Bajaj V12 Dimensions**
#
#                                               Content
# 0   The Bajaj V12 is a commuter motorcycle based o...
# 1   – The Bajaj V12 takes its styling inspiration ...
# 2   – The instrument cluster here is carried from ...
# 3   – Like the V15, the V12 also features a city c...
# 4   – What powers the new Bajaj V12 is a single-cy...
# 5   – The Bajaj V12 offers a commanding upright si...
# 6   – The V15 proved out to be a great success for...
# 7   * Torquey nature of the engine with good low-e...
# 8   * The butterfly-shaped headlamp design does no...
# 9   * Engine: 124.5cc, single-cylinder, 2-valve, D...
# 10  * Length x Width x Height: 2040 mm x 785 mm x ...
#
# Processing file: bajaj-avenger-street-150-test-ride-review.txt
#                                       Bold Text  \
# 0                  **Bajaj Avenger 150 Review**
# 1                                   **Styling**
# 2         **Instrument Cluster and Switchgear**
# 3                                **Ergonomics**
# 4                               **Performance**
# 5                           **Riding Dynamics**
# 6                                   **Verdict**
# 7                               **What’s Cool**
# 8                        **What’s Not So Cool**
# 9   **Bajaj Avenger Street 150 Specifications**
# 10      **Bajaj Avenger Street 150 Dimensions**
# 11                           **Testers’ Note:**
#
#                                               Content
# 0   The Avenger Street 150 is the cheapest cruiser...
# 1   – The Street 220 and Street 150 in the Avenger...
# 2   – The instrument cluster is a simple unit but ...
# 3   – Being a cruiser, the seating position is com...
# 4   – Bajaj Auto has plonked the same 150cc, 2-val...
# 5   – The Avenger Street 150 shares the same under...
# 6   – A 150cc cruiser might sound like a ridiculou...
# 7   * Sporty looking cruiser with good attention t...
# 8   * More powerful engine would have made this 15...
# 9   * Engine: 149cc, single-cylinder, air-cooled, ...
# 10  * Length x Width x Height: 2177 mm x 801 mm x ...
# 11  “The Avenger Street 150’s performance was quit...
#
# Processing file: bajaj-pulsar-125-review-test-ride.txt
#                                    Bold Text  \
# 0           **Bajaj Pulsar 125 Neon Review**
# 1                                **Styling**
# 2      **Instrument Cluster and Switchgear**
# 3                             **Ergonomics**
# 4                            **Performance**
# 5                        **Riding Dynamics**
# 6                                **Verdict**
# 7                            **What’s Cool**
# 8                     **What’s Not So Cool**
# 9   **Bajaj Pulsar 125 Neon Specifications**
# 10      **Bajaj Pulsar 125 Neon Dimensions**
#
#                                               Content
# 0   The Pulsar 125 Neon makes the ‘Definitely Male...
# 1   – As said earlier, the Pulsar 125 Neon is base...
# 2   – The Pulsar 125 Neon boasts the same old inst...
# 3   – Pulsars have always been known for great rid...
# 4   – The Pulsar 125 Neon is powered by a 124.4cc ...
# 5   – The suspension, brakes, tyres are all carrie...
# 6   – The Pulsar 125 Neon, a new entry-level commu...
# 7   * Peppy styling with neon highlights look good...
# 8   * Motorcycle feels heavy for the performance *...
# 9   * Engine: 124.4cc, Air-Cooled, 4-Stroke, Singl...
# 10  * Length x Width x Height: 2055 mm x 755 mm x ...
#
# Processing file: bajaj-pulsar-rs-200-test-ride-review.txt
#                                 Bold Text  \
# 0          **Bajaj Pulsar RS 200 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9        **Pulsar RS 200 Specifications**
# 10           **Pulsar RS 200 Dimensions**
# 11                     **Testers’ Note:**
#
#                                               Content
# 0   The Pulsar RS 200 makes for a practical street...
# 1   – The Pulsar RS 200 gets a full fairing and it...
# 2   – The same instrument cluster as the other 200...
# 3   – One sits upright with a bit of a lean, thus ...
# 4   – The Pulsar RS 200 uses the same engine as th...
# 5   – Using the same chassis as the 200 NS, Bajaj ...
# 6   – The Bajaj Pulsar RS 200 delivers all that it...
# 7   * Full faired design means those who want a sp...
# 8   * Single-channel ABS is only half the use, for...
# 9   * Engine: 199.5cc, single-cylinder, SOHC, liqu...
# 10  * Length x Width x Height: 1999 mm x 765 mm x ...
# 11  “Call me crazy but the design of the Pulsar RS...
#
# Processing file: 2018-bajaj-avenger-180-review-test-ride.txt
#                                     Bold Text  \
# 0                **Bajaj Avenger 180 Review**
# 1                                 **Styling**
# 2       **Instrument Cluster and Switchgear**
# 3                              **Ergonomics**
# 4                             **Performance**
# 5                         **Riding Dynamics**
# 6                                 **Verdict**
# 7                             **What’s Cool**
# 8                      **What’s Not So Cool**
# 9   **2018 Bajaj Avenger 180 Specifications**
# 10      **2018 Bajaj Avenger 180 Dimensions**
#
#                                               Content
# 0   The Avenger 180 has made a comeback after 13 y...
# 1   – The new Avenger Street 180 is now the entry-...
# 2   – The instrument cluster on this Street 180 is...
# 3   – The Avenger 180 offers a very relaxed and co...
# 4   – The 2018 Avenger Street 180 is powered by a ...
# 5   – The 2018 Avenger 180 is a low and easy to ac...
# 6   – The new Avenger Street 180 is the latest add...
# 7   * Design and modern looks * Engine refinement ...
# 8   * Front disc brake lacks bite * Vibrations kic...
# 9   * Engine: 178.6cc, 178.6cc, Twin-Spark, 2-Valv...
# 10  * Length x Width x Height: 2210 mm x 806 mm x ...
#
# Processing file: bajaj-pulsar-220-review-test-ride.txt
#                                 Bold Text  \
# 0                   **Pulsar 220 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9     **Bajaj Pulsar 220 Specifications**
# 10        **Bajaj Pulsar 220 Dimensions**
#
#                                               Content
# 0   At this price, the Bajaj Pulsar 220’s tourer-f...
# 1   – Back in 2007, the Pulsar 220’s proportionate...
# 2   – Tucked away under the Bajaj Pulsar 220’s tin...
# 3   – When it comes to seating, the Pulsar 220 has...
# 4   – The Bajaj Pulsar 220’s most far-reaching cha...
# 5   – Compare it to its Perimeter frame-equipped r...
# 6   – Bajaj Pulsar 220 is the one that started it ...
# 7   * Torquey 220cc oil-cooled motor has ample gru...
# 8   * Chassis and suspension setup tuned for ride ...
# 9   * Engine: 220cc, Oil-Cooled, 4-Stroke, Single-...
# 10  * Length x Width x Height: 2035 mm x 750 mm x ...
#
# Processing file: bajaj-dominar-250-review-test-ride.txt
#                                     Bold Text  \
# 0                **Bajaj Dominar 250 Review**
# 1                                **Styling:**
# 2      **Instrument Cluster and Switchgear:**
# 3                             **Ergonomics:**
# 4                            **Performance:**
# 5                        **Riding Dynamics:**
# 6                                **Verdict:**
# 7                             **What’s Cool**
# 8                      **What’s Not So Cool**
# 9   **2020 Bajaj Dominar 250 Specifications**
# 10      **2020 Bajaj Dominar 250 Dimensions**
#
#                                               Content
# 0   The Dominar 250 is the first quarter-litre mot...
# 1   If you like how the Bajaj Dominar 400 looks, y...
# 2   Like the physical appearance, the Bajaj Domina...
# 3   The Bajaj Dominar was always a comfortable mot...
# 4   The Bajaj Dominar 250 gets a single-cylinder, ...
# 5   The Bajaj Dominar 250 shares its ergonomics wi...
# 6   The Dominar 250 gets a majority of its compone...
# 7   * The cheapest 250cc naked bike offering in th...
# 8   * Could have been lighter* Only available in 2...
# 9   * Engine: 248.8cc, Liquid-Cooled, Single-Cylin...
# 10  * Length x Width x Height: 2156 mm x 836 mm x ...
#
# Processing file: 2015-bajaj-platina-100-es-test-ride-review.txt
#                                   Bold Text  \
# 0           **Bajaj Platina 100 ES Review**
# 1                               **Styling**
# 2     **Instrument Cluster and Switchgear**
# 3                            **Ergonomics**
# 4                           **Performance**
# 5                       **Riding Dynamics**
# 6                               **Verdict**
# 7                           **What’s Cool**
# 8                    **What’s Not So Cool**
# 9   **Bajaj Platina 100 ES Specifications**
# 10      **Bajaj Platina 100 ES Dimensions**
#
#                                               Content
# 0   The Platina 100 ES offers mileage and ease of ...
# 1   – Being a commuter motorcycle, styling and des...
# 2   – The console meter on this bike is very sweet...
# 3   – The seating position is upright and the hand...
# 4   – The Bajaj Platina 100 ES is powered by a new...
# 5   – The refreshed Platina 100 ES now becomes big...
# 6   – The Platina 100 ES being a 100cc motorcycle ...
# 7   * Engine refinement and mileage, this bike sip...
# 8   * Brakes aren’t as powerful but do a decent jo...
# 9   * Engine: 102cc, 2-valve, single-cylinder, air...
# 10  * Length x Width x Height: 2000 mm x 840 mm x ...
#
# Processing file: 2019-bajaj-dominar-400-review-test-ride.txt
#                                 Bold Text  \
# 0       **2019 Bajaj Dominar 400 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9    **Bajaj Dominar 400 Specifications**
# 10       **Bajaj Dominar 400 Dimensions**
#
#                                               Content
# 0   With this update, the Bajaj Dominar 400 gets e...
# 1   – The Dominar 400 hasn’t changed much when you...
# 2   – Bajaj has kept the primary instrument cluste...
# 3   –  The ergonomics stay exactly the same betwee...
# 4   – There is a huge difference in terms of power...
# 5   – Riding dynamics are now much better due to a...
# 6   – The Dominar 400 now looks considerably fresh...
# 7   * The USD forks and a slew of changes give it ...
# 8   * The pillion seat is still a bit too narrow f...
# 9   * Engine: 373.2cc, liquid cooled, DOHC * Power...
# 10  * Length x Width x Height: 2156 mm x 836 mm x ...
#
# Processing file: bajaj-v15-review-test-ride.txt
#                                 Bold Text  \
# 0                    **Bajaj V15 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9            **Bajaj V15 Specifications**
# 10               **Bajaj V15 Dimensions**
# 11                      **Testers’ Note**
#
#                                               Content
# 0   The Bajaj V15 is a very differentiated commute...
# 1   – The Bajaj V15 has a unique appeal in the sty...
# 2   – Almost every new motorcycle in the current m...
# 3   – The Bajaj V15 is a city commuter and ergonom...
# 4   – The Bajaj V15 is made for a person who doesn...
# 5   – Riding a commuter is never fun, instead it’s...
# 6   – The Bajaj V15 is another 150cc motorcycle in...
# 7   * Torquey engine has good mid-range perfect fo...
# 8   * Front headlamp design does not go with the b...
# 9   * Engine: 149.5cc, single-cylinder, 2-valve, D...
# 10  * Length x Width x Height: 2044 mm x 780 mm x ...
# 11  :\n“The Bajaj V15 is a marketing master-stroke...
#
# Processing file: bajaj-avenger-street-220-cruise-220-test-ride-review.txt
#                                             Bold Text  \
# 0                        **Bajaj Avenger 220 Review**
# 1                                         **Styling**
# 2               **Instrument Cluster and Switchgear**
# 3                                      **Ergonomics**
# 4                                     **Performance**
# 5                                 **Riding Dynamics**
# 6                                         **Verdict**
# 7                                     **What’s Cool**
# 8                              **What’s Not So Cool**
# 9   **Bajaj Avenger Street 220 & Cruise 220 Specif...
# 10  **Bajaj Avenger Street 220/Cruise 220 Dimensio...
# 11                                 **Testers’ Note:**
#
#                                               Content
# 0   The Bajaj Avenger 220 largely gets cosmetic ch...
# 1   – Starting with the Avenger Cruise 220, the ch...
# 2   – Both bikes share the same instrument console...
# 3   – Here lies the big differentiator between the...
# 4   – The same 220cc powerplant continues on the n...
# 5   – Bajaj Auto has made some changes like added ...
# 6   – Bajaj Auto took a long time to update the Av...
# 7   * Freshened up styling, the Street 220 looks s...
# 8   * No updates to the power or torque * No tubel...
# 9   * Engine: 219.9cc, single-cylinder, oil-cooled...
# 10  * Length x Width x Height: 2177 mm x 801/806 m...
# 11  “The Avenger Cruise 220 doesn’t bring much new...
#
# Processing file: bajaj-platina-110-h-gear-review-test-ride.txt
#                                       Bold Text  \
# 0           **Bajaj Platina 110 H Gear Review**
# 1                                   **Styling**
# 2         **Instrument Cluster and Switchgear**
# 3                                **Ergonomics**
# 4                               **Performance**
# 5                           **Riding Dynamics**
# 6                                   **Verdict**
# 7                               **What’s Cool**
# 8                        **What’s Not So Cool**
# 9   **Bajaj Platina 110 H Gear Specifications**
# 10      **Bajaj Platina 110 H Gear Dimensions**
#
#                                               Content
# 0   The Bajaj Platina 110 is an entry-level 110cc ...
# 1   – On the styling front, the Platina does not h...
# 2   – Alongside the visual changes, the cluster is...
# 3   – The ergonomics of the Platina H Gear have be...
# 4   – Powered by the same 115.5cc motor, the Bajaj...
# 5   – The ergonomics have been continued and hence...
# 6   – The Bajaj Platina 110 was the entry-level mo...
# 7   * 5-speed gearbox is unique and helpful * Susp...
# 8   * Overall fit and finish feels quite basic * T...
# 9   * Engine: 115.5cc, Air-Cooled, Single-Cylinder...
# 10  * Length x Width x Height: 2006 mm x 704 mm x ...
#
# Processing file: bajaj-dominar-400-review-test-ride.txt
#                                 Bold Text  \
# 0            **Bajaj Dominar 400 Review**
# 1                             **Styling**
# 2   **Instrument Cluster and Switchgear**
# 3                          **Ergonomics**
# 4                         **Performance**
# 5                     **Riding Dynamics**
# 6                             **Verdict**
# 7                         **What’s Cool**
# 8                  **What’s Not So Cool**
# 9    **Bajaj Dominar 400 Specifications**
# 10       **Bajaj Dominar 400 Dimensions**
# 11                      **Testers’ Note**
#
#                                               Content
# 0   The Dominar 400 offers the most performance & ...
# 1   – Complete glance and the Bajaj Dominar 400 lo...
# 2   – The Bajaj Dominar 400 gets a dual instrument...
# 3   – At 800 mm, the seat height of the Dominar 40...
# 4   – Though the numbers from the Dominar’s mill m...
# 5   – The Dominar 400 is a gem on the straights wh...
# 6   – The Dominar 400 is a complete package, has t...
# 7   * Amazing hardware on offer with a killer pric...
# 8   * Tyres and feedback from brakes could have be...
# 9   * Engine: 373.2cc, 4-valve, Triple-Spark, Liqu...
# 10  * Length x Width x Height: 2156 mm x 813 mm x ...
# 11  :\n“Bajaj has positioned the Dominar 400 in su...
#
# Processing file: bajaj-discover-110-review-test-ride.txt
#                                      Bold Text  \
# 0                **Bajaj Discover 110 Review**
# 1                                  **Styling**
# 2        **Instrument Cluster and Switchgear**
# 3                               **Ergonomics**
# 4                              **Performance**
# 5                          **Riding Dynamics**
# 6                                  **Verdict**
# 7                              **What’s Cool**
# 8                       **What’s Not So Cool**
# 9   **2018 Bajaj Discover 110 Specifications**
# 10      **2018 Bajaj Discover 110 Dimensions**
#
#                                               Content
# 0   The 2018 Discover 110 sits between the Platina...
# 1   – The 2018 Discover 110 still carries the desi...
# 2   – The instrument cluster on this new model is ...
# 3   – The Discover 110 offers city commuter ergono...
# 4   – The 2018 Discover 110 is powered by a long s...
# 5   – As said before, the Discover 110 offers an u...
# 6   – Bajaj Auto has done a great job on the Disco...
# 7   * Torquey nature of the engine has a lot of go...
# 8   * Front drum brakes lack feel and feedback * T...
# 9   * Engine: 115.45cc, single-cylinder, DTS-i * P...
# 10  * Length x Width x Height: 2035 mm x 760 mm x ...
